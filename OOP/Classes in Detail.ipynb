# %%
class Student:
  def __init__(self,name,roll_num,marks):
    self.studentName = name
    self.studentRoll = roll_num
    self.studentMarks = marks

# %%
student1 = Student('Kushal', 123, 500)

# %%
student1.studentName
# Out:
# 'Kushal'
