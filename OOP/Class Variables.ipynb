# %%
class Student:
  total_marks = 1000
  def __init__(self, name, age, marks):
    self.name = name
    self.age = age
    self.marks = marks
    self.total_marks = Student.total_marks

# %%
s1 = Student('Kushal', 31, 500)

# %%
s1.total_marks
# Out:
# 1000

# %% [markdown]
# Exercise:
#
# Define a class Circle with two methods: circumference and area

# %%
# not good, see below for good

class Circle:
  def __init__(self, radius, pi):
    self.radius = radius
    self.pi = pi
  def circle_circumference(self):
    value = 2*self.pi*self.radius
    return value
  def circle_area(self):
    value = self.pi*self.radius**2
    return value

# %%
c1 = Circle(23, 3.14)
c2 = Circle(24, 3.14)

# %%
c1.radius
# Out:
# 23

# %%
c2.circle_circumference()
# Out:
# 150.72

# %%
c2.circle_area()
# Out:
# 1808.64

# %%
class Circle:
  pi = 3.14
  def __init__(self, radius):
    self.radius = radius
  def circle_circumference(self):
    value = 2*Circle.pi*self.radius
    return value
  def circle_area(self):
    value = Circle.pi*self.radius**2
    return value

# %%
c1 = Circle(24)

# %%
c1.circle_area()
# Out:
# 1808.64

# %%
c1.circle_circumference()
# Out:
# 150.72
