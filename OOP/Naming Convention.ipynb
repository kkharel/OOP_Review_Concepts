# %%
# In Python language, everything is public variable

# %%
# _price: this variable is a private variable

# %%
class Phone: # Base Class / Parent Class
  def __init__(self, brand, model_name, price):
    self.brand = brand
    self.model_name = model_name
    self.price = max(0, price)
    self._discount = 5
  def apply_discount(self):
    discounted = (self.price/100) * self._discount
    final_price = self.price - discounted
    return final_price

# %%
phone1 = Phone("Nokia", '1600', 4000)

# %%
phone1.__dict__
# Out:
# {'brand': 'Nokia', 'model_name': '1600', 'price': 4000, '_discount': 5}

# %%
phone1.apply_discount()
# Out:
# 3800.0

# %%
phone1._discount = 2

# %%
phone1.__dict__
# Out:
# {'brand': 'Nokia', 'model_name': '1600', 'price': 4000, '_discount': 2}

# %%
phone1.apply_discount()
# Out:
# 3920.0

# %%
# __name__ : Dunder or Magic Method
