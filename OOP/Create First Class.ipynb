# %%
class Student:
  def __init__(self, name, roll_num,marks):
    self.name = name
    self.roll_num = roll_num
    self.marks = marks

# %%
student1 = Student("Kushal", 123, 500)

# %%
student1

# %%
student1.name
# Out:
# 'Kushal'

# %%
student2 = Student("Kharel", 234, 600)

# %%
student2.name
# Out:
# 'Kharel'
