# %%
class Product:
  def __init__(self, productname, brandname, modelname, price):
    self.productname = productname
    self.brandname = brandname
    self.modelname = modelname
    self.price = price
    self.productnamewithmodelname = productname + ' ' + modelname

# %%
p1 = Product('k', 'u', 's', 500)

# %%
p1.productnamewithmodelname
# Out:
# 'k s'
