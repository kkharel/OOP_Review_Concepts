# %%
class Phone:
  def __init__(self, brand, model_name, price):
    self.brand = brand
    self.model_name = model_name
    # if price > 0:
    #   self.price = price
    # else:
    #   self.price = 0
    self.price = max(0, price)
    # self.completeSpecification = f"{self.brand} {self.model_name} and price is {self.price}"
  @property # this helps us not call below function with parentheses
  def completeSpecification(self):
    return f"{self.brand} {self.model_name} and price is {self.price}"

  @staticmethod
  def make_a_call(phone_num):
    print(f"Calling {phone_num}...")

  def full_name(self):
    return f"{self.brand} {self.brand_name}"

# %%
phone1 = Phone('Nokia', '1100', -5000)

# %%
phone1.brand
# Out:
# 'Nokia'

# %%
phone1.model_name
# Out:
# '1100'

# %%
phone1.price
# Out:
# 0

# %%
phone1.completeSpecification
# Out:
# 'Nokia 1100 and price is 0'

# %%
phone1.price = 2000

# %%
phone1.price
# Out:
# 2000

# %%
phone1.completeSpecification
# Out:
# 'Nokia 1100 and price is 2000'
