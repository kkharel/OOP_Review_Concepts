# %%
class Laptop:
  discount = 10
  sno = 1
  def __init__(self, name, price):
    Laptop.sno += 1
    self.sno = Laptop.sno
    self.price = price
    self.name = name
  def apply_discount(self):
    discount_amount = (self.price/100)*self.discount
    final_price = self.price - discount_amount
    return int(final_price)

# %%
m6600 = Laptop('m6600', 5500)

# %%
m4800 = Laptop('m4800', 5500)

# %%
m4800.__dict__
# Out:
# {'sno': 3, 'price': 5500, 'name': 'm4800'}

# %%
m4800.bluetooth = 'yes'

# %%
m4800.__dict__
# Out:
# {'sno': 3, 'price': 5500, 'name': 'm4800', 'bluetooth': 'yes'}

# %%
m6600.apply_discount()
# Out:
# 4950

# %%
m4800.apply_discount()
# Out:
# 4950

# %%
m4800.discount = 5

# %%
m4800.__dict__
# Out:
# {'sno': 3, 'price': 5500, 'name': 'm4800', 'bluetooth': 'yes', 'discount': 5}

# %%
m6600.__dict__
# Out:
# {'sno': 2, 'price': 5500, 'name': 'm6600'}

# %%
m4800.apply_discount()
# Out:
# 5225

# %%
m6600.apply_discount()
# Out:
# 4950

# %%
m7710 = Laptop('m7710', 4500)

# %%
m7710.discount = 3

# %%
m7710.__dict__
# Out:
# {'sno': 4, 'price': 4500, 'name': 'm7710', 'discount': 3}

# %%
m7710.apply_discount()
# Out:
# 4365

# %%
m6610 = Laptop('m6610', 400)

# %%
m6610.discount = 0

# %%
m6610.__dict__
# Out:
# {'sno': 5, 'price': 400, 'name': 'm6610', 'discount': 0}

# %%
m6610.apply_discount()
# Out:
# 400
